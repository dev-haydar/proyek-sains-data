# %% [markdown]
# ## 1. Mendeskripsikan data
# Sepal length > Float
# Sepal Width > Float
# Petal Length > Float
# Petal Width > Float
# Species > Varchar

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Tarik Database ke Aplikasi Power BI

# %% [markdown]
# ![Cuplikan layar 2025-09-08 101751.png](data:image/png;base64,...)

# %% [markdown]
# Setelah menarik data ke dalam power bi visualisasi kan data ke power bi

# %% [markdown]
# ![image.png](data:image/png;base64,...)
